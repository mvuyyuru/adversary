# %%
import os
import matplotlib.pyplot as plt

# %%
os.chdir('..')

# %%
#os.getcwd()

# %% [markdown]
# # without nvidia determinism patch

# %%
# !head -n 15 adversary.py
# Out:
# import os
# import pickle
# import warnings
# import argparse
# import datasets
# import model_backbone
# import attack_backbone
#
# import numpy as np
# import tensorflow as tf
# from functools import partial
#
# #patch for deterministic tensorflow ops on tf20
# #from tfdeterminism import patch
# #patch()

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:27:49.858823: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:27:49.945751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:27:49.948029: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:27:49.978983: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:27:50.022156: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:27:50.095876: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:28:43.540428: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:28:43.625925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:28:43.627588: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:28:43.651664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:28:43.677152: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:28:43.733945: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:29:38.770421: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:29:38.859263: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:29:38.861399: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:29:38.895927: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:29:38.939367: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:29:39.014378: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:30:31.752705: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:30:31.848861: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:30:31.850522: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:30:31.871234: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:30:31.893984: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:30:31.951592: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:31:36.730369: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:31:36.819715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:31:36.823056: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:31:36.854770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:31:36.896296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:31:36.968959: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:45:08.663015: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:45:08.750418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:45:08.752678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:45:08.789040: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:45:08.836012: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:45:08.909838: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:46:42.652385: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:46:42.741203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:46:42.743837: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:46:42.781174: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:46:42.805391: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:46:42.867454: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:48:53.026979: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:48:53.123401: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:48:53.124252: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:48:53.135453: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:48:53.152985: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:48:53.193261: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:49:44.863554: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:49:44.944527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:49:44.947624: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:49:44.961556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:49:44.975725: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:49:44.998799: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# 2020-01-20 23:50:38.607561: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:50:38.710410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:50:38.746439: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:50:38.769971: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:50:38.799135: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-01-20 23:50:38.833552: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# ...

# %%
loss_values = [0.4071944057941437, 0.40719446539878845, 0.40719446539878845, 0.4071945250034332, 0.4071944057941437, 0.4071944057941437, 0.40719446539878845, 0.4071944057941437, 0.40719446539878845, 0.4071944057941437]
plt.hist(loss_values, edgecolor='k')
plt.show()

# %% [markdown]
# # with nvidia determinism patch

# %%
# !head -n 15 adversary.py
# Out:
# import os
# import pickle
# import warnings
# import argparse
# import datasets
# import model_backbone
# import attack_backbone
#
# import numpy as np
# import tensorflow as tf
# from functools import partial
#
# #patch for deterministic tensorflow ops on tf20
# from tfdeterminism import patch
# patch()

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:35:50.863957: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:35:50.938600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:35:50.939289: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:35:50.953431: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:35:51.007404: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:36:49.934318: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:36:50.027350: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:36:50.044093: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:36:50.074616: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:36:50.099736: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:37:43.791779: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:37:43.877482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:37:43.879317: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:37:43.892912: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:37:43.905776: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:38:40.132289: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:38:40.201533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:38:40.203563: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:38:40.216509: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:38:40.231905: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:39:33.091826: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:39:33.202753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:39:33.203676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:39:33.254555: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:39:33.312391: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:57:41.209556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:57:41.296709: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:57:41.312768: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:57:41.352506: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:57:41.403610: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:58:40.097257: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:58:40.185421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:58:40.186122: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:58:40.188741: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:58:40.204212: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-20 23:59:34.991520: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-20 23:59:35.066881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-20 23:59:35.067632: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-20 23:59:35.082870: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-20 23:59:35.091842: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-21 00:00:35.628643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-21 00:00:35.713474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-21 00:00:35.715771: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-21 00:00:35.749129: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-21 00:00:35.775556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-21 00:01:27.434964: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-21 00:01:27.527648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-21 00:01:27.529991: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-21 00:01:27.546180: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-21 00:01:27.560848: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
# !python adversary.py --name=CNNwSAMPLINGwoFIXATIONS_distributed --model=resnet --dataset=imagenet10 --sampling=1 --coarse_fixations=0 --evaluate_mode=robustness --evaluate_submode=LINF
# Out:
# TensorFlow version 2.0.0 has been patched using tfdeterminism version 0.3.0
# 2020-01-21 00:03:26.660276: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-01-21 00:03:26.755978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:88:00.0
# 2020-01-21 00:03:26.758175: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-01-21 00:03:26.771814: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-01-21 00:03:26.786238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# ...

# %%
loss_values = [0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989, 0.4071943461894989]
plt.hist(loss_values, edgecolor='k')
plt.show()
